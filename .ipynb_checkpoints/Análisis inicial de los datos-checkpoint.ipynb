# %% [markdown]
# ## ANÁLISIS INICIAL EXPLORATORIO

# %% [markdown]
# En este Notebook se hace un análisis inicial de la estructura de los datos, para asegurar el esquema de preprocesamiento que se aplicará más adelante a la señal de EEG.

# %% [markdown]
# IMPORT MODULES

# %%
import mne
from TFG_utils import returnFiles, take_vmrk_files, take_vhdr_files, take_eeg_files, Get_Start_End_mrk, Get_spot_start_samples, plot_spots
import matplotlib.pyplot as plt
import numpy as np
mne.__version__
#%matplotlib qt
# Out:
# '0.20.7'

# %% [markdown]
# ### COLLECTING DATA FROM FOLDERS

# %%
foldername = 'EEG_folders'
EEG_files=returnFiles(foldername)
print('Hay',len(EEG_files),'carpetas de EEG')
# Out:
# Hay 5 carpetas de EEG

# %%
vmrk_files=take_vmrk_files(EEG_files)
vhdr_files=take_vhdr_files(EEG_files)
eeg_files=take_eeg_files(EEG_files)

# %%
i=3 # Choosing EEG recording to use 

vmrk_filename=vmrk_files[i]
vhdr_filename=vhdr_files[i]
eeg_filename=eeg_files[i]

print('\n',eeg_filename,'\n',vhdr_filename,'\n',vmrk_filename)
# Out:
#  EEG_folders\eeg_example_5\Neuromarketing2900.eeg
#  EEG_folders\eeg_example_5\Neuromarketing2900.vhdr
#  EEG_folders\eeg_example_5\Neuromarketing2900.vmrk

# %%
raw_eeg = mne.io.read_raw_brainvision(vhdr_files[i],verbose=True).load_data(verbose=True)
info=raw_eeg.info
# Out:
# Extracting parameters from EEG_folders\eeg_example_5\Neuromarketing2900.vhdr...
# Setting channel info structure...
# Reading 0 ... 252619  =      0.000 ...   505.238 secs...

# %%
#Select channel to represent:
ch = 2 #Channel F3
#ch = 3 #Channel F7
#ch = 28 #Channel F4
#ch = 29 #Channel F8

# %%
subject=eeg_filename[-8:-4]
print('Sujeto:',subject)
print('Canal:', info['ch_names'][ch])
# Out:
# Sujeto: 2900
# Canal: F3

# %% [markdown]
# ### DATA STRUCTURE

# %%
raw_eeg
# Out:
# <RawBrainVision | Neuromarketing2900.eeg, 31 x 252620 (505.2 s), ~59.8 MB, data loaded>

# %%
print('Hay', info['nchan'],'canales:')
print(info['ch_names']) # Número y nombre de los canales
# Out:
# Hay 31 canales:
# ['Fp1', 'Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'TP9', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'Fp2']

# %%
print('Hay',raw_eeg.n_times,'muestras de tiempo') # Número de muestras de tiempo
# Out:
# Hay 252620 muestras de tiempo

# %%
fs=info['sfreq']
print('La frecuencia de muestreo es:',fs,'Hz')
# Out:
# La frecuencia de muestreo es: 500.0 Hz

# %% [markdown]
# ### REPRESENTACIÓN GRÁFICA

# %%
plot_spots(vmrk_filename,raw_eeg,ch)

# %%
plt.figure(figsize=(12,5))
ax = plt.axes()
raw_eeg.plot_psd(area_mode='std', ax=ax, dB=True, show=False, average=True, estimate='power', line_alpha=None, color='green')
ax.set_title('Power Spectrum Density (PSD)', fontsize=16)
plt.show()
# Out:
# Effective window size : 4.096 (s)
